# %%
# import numpy, pandas, seaborn, matplotlib just because
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

import pickle

from fbprophet import Prophet
from fbprophet.plot import add_changepoints_to_plot
from fbprophet.plot import plot

#ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Time series forecasting on COVID-19

# %%
covid = pd.read_csv('https://usafactsstatic.blob.core.windows.net/public/data/covid-19/covid_confirmed_usafacts.csv')
covid = covid.groupby(['State']).sum()
covid.drop(['countyFIPS', 'stateFIPS'], axis=1, inplace=True)
covid = covid.transpose()
covid = covid.reset_index()
covid = covid.rename_axis('', axis=1)
covid = covid.rename(columns={'index':'date'})
covid.columns= covid.columns.str.lower()
covid['overall'] = covid.iloc[:,0:].sum(axis=1)

# %%
covid.tail()
# Out:
#         date    ak      al     ar      az      ca     co     ct     dc     de  \
# 231   9/9/20  5896  134416  66402  206541  747809  59917  53871  14387  18308
# 232  9/10/20  6020  135565  66804  206993  750062  60183  54093  14412  18466
# 233  9/11/20  6112  136703  67911  207521  755495  60491  54326  14493  18559
# 234  9/12/20  6216  137646  68309  208126  758504  60907  54326  14552  18726
# 235  9/13/20  6278  138755  68487  208512  760490  61325  54326  14592  18849
#
#      ...      tn      tx     ut      va    vt     wa     wi     wv    wy  \
# 231  ...  166587  654570  55689  129283  1654  78007  83333  11803  4151
# 232  ...  168237  658588  56048  130519  1660  78464  84880  12003  4197
# 233  ...  169856  662083  56657  131637  1668  79011  86250  12170  4261
# 234  ...  170891  666525  57300  132939  1677  79476  87603  12521  4294
# 235  ...  171824  670029  58666  133814  1684  79826  89185  12699  4344
#
#      overall
# 231  6311305
# 232  6346829
# 233  6393202
# 234  6432407
# 235  6466472
#
# [5 rows x 53 columns]

# %%
covid_az = covid[['date', 'az']].copy()
covid_fl = covid[['date', 'fl']].copy()
covid_ga = covid[['date', 'ga']].copy()
covid_ia = covid[['date', 'ia']].copy()
covid_mi = covid[['date', 'mi']].copy()
covid_nv = covid[['date', 'nv']].copy()
covid_nh = covid[['date', 'nh']].copy()
covid_nc = covid[['date', 'nc']].copy()
covid_oh = covid[['date', 'oh']].copy()
covid_pa = covid[['date', 'pa']].copy()
covid_tx = covid[['date', 'tx']].copy()
covid_wi = covid[['date', 'wi']].copy()
covid_overall = covid[['date', 'overall']].copy()

# %%
covid_az.rename(columns={covid_az.columns[0]: "ds", covid_az.columns[1]: "y"}, inplace = True)
covid_fl.rename(columns={covid_fl.columns[0]: "ds", covid_fl.columns[1]: "y"}, inplace = True)
covid_ga.rename(columns={covid_ga.columns[0]: "ds", covid_ga.columns[1]: "y"}, inplace = True)
covid_ia.rename(columns={covid_ia.columns[0]: "ds", covid_ia.columns[1]: "y"}, inplace = True)
covid_mi.rename(columns={covid_mi.columns[0]: "ds", covid_mi.columns[1]: "y"}, inplace = True)
covid_nv.rename(columns={covid_nv.columns[0]: "ds", covid_nv.columns[1]: "y"}, inplace = True)
covid_nh.rename(columns={covid_nh.columns[0]: "ds", covid_nh.columns[1]: "y"}, inplace = True)
covid_nc.rename(columns={covid_nc.columns[0]: "ds", covid_nc.columns[1]: "y"}, inplace = True)
covid_oh.rename(columns={covid_oh.columns[0]: "ds", covid_oh.columns[1]: "y"}, inplace = True)
covid_pa.rename(columns={covid_pa.columns[0]: "ds", covid_pa.columns[1]: "y"}, inplace = True)
covid_tx.rename(columns={covid_tx.columns[0]: "ds", covid_tx.columns[1]: "y"}, inplace = True)
covid_wi.rename(columns={covid_wi.columns[0]: "ds", covid_wi.columns[1]: "y"}, inplace = True)
covid_overall.rename(columns={covid_overall.columns[0]: "ds", covid_overall.columns[1]: "y"}, inplace = True)

# %%
model = Prophet()
model.fit(covid_overall)
# Out:
# INFO:numexpr.utils:Note: NumExpr detected 12 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# INFO:numexpr.utils:NumExpr defaulting to 8 threads.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
covid_overall.tail()
# Out:
#           ds        y
# 231   9/9/20  6311305
# 232  9/10/20  6346829
# 233  9/11/20  6393202
# 234  9/12/20  6432407
# 235  9/13/20  6466472

# %%
future = model.make_future_dataframe(periods=60) # set periods to number making the final date 2020-11-03
future.shape
# Out:
# (296, 1)

# %%
future.tail()
# Out:
#             ds
# 291 2020-11-08
# 292 2020-11-09
# 293 2020-11-10
# 294 2020-11-11
# 295 2020-11-12

# %%
forecast = model.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#             ds          yhat    yhat_lower    yhat_upper
# 291 2020-11-08  9.143992e+06  8.518241e+06  9.788130e+06
# 292 2020-11-09  9.188287e+06  8.539607e+06  9.849667e+06
# 293 2020-11-10  9.232614e+06  8.565316e+06  9.898205e+06
# 294 2020-11-11  9.278501e+06  8.598605e+06  9.968807e+06
# 295 2020-11-12  9.326720e+06  8.614626e+06  1.003064e+07

# %%
forecast.head()
# Out:
#           ds       trend    yhat_lower    yhat_upper  trend_lower  \
# 0 2020-01-22 -492.580537 -35420.955928  29263.238481  -492.580537
# 1 2020-01-23 -478.732208 -35646.245345  30958.719571  -478.732208
# 2 2020-01-24 -464.883880 -30215.490698  34542.607513  -464.883880
# 3 2020-01-25 -451.035551 -29144.820664  37219.894749  -451.035551
# 4 2020-01-26 -437.187222 -34377.358064  32221.794733  -437.187222
#
#    trend_upper  additive_terms  additive_terms_lower  additive_terms_upper  \
# 0  -492.580537    -3039.555334          -3039.555334          -3039.555334
# 1  -478.732208     -789.938709           -789.938709           -789.938709
# 2  -464.883880     3205.810439           3205.810439           3205.810439
# 3  -451.035551     4539.686622           4539.686622           4539.686622
# 4  -437.187222      357.751048            357.751048            357.751048
#
#         weekly  weekly_lower  weekly_upper  multiplicative_terms  \
# 0 -3039.555334  -3039.555334  -3039.555334                   0.0
# 1  -789.938709   -789.938709   -789.938709                   0.0
# 2  3205.810439   3205.810439   3205.810439                   0.0
# 3  4539.686622   4539.686622   4539.686622                   0.0
# 4   357.751048    357.751048    357.751048                   0.0
#
#    multiplicative_terms_lower  multiplicative_terms_upper         yhat
# 0                         0.0                         0.0 -3532.135871
# 1                         0.0                         0.0 -1268.670917
# 2                         0.0                         0.0  2740.926559
# 3                         0.0                         0.0  4088.651071
# 4                         0.0                         0.0   -79.436174

# %%
fig1 = model.plot(forecast, figsize=(8, 12))
# plt.title('US COVID-19 Forecast', fontsize = 30)
plt.xlabel('Date', fontsize = 16)
plt.ylabel('Cases', fontsize = 16)
plt.grid(b=None)

# %%
fig2 = model.plot_components(forecast)

# %%
fig = model.plot(forecast, figsize=(15, 8))
a = add_changepoints_to_plot(fig.gca(), model, forecast)
plt.title('US COVID-19 Forecast to 11/3/2020', fontsize = 30)
plt.xlabel('Date', fontsize = 16)
plt.ylabel('Cases', fontsize = 16)
# Out:
# Text(108.125, 0.5, 'Cases')

# %% [markdown]
# # Time series forecasting on Biden vs Trump polling

# %%
#change the csv being read to the reflective state to view the forecast
poll = pd.read_csv('polls_wi.csv')

# %%
poll.head()
# Out:
#   state                         pollster  \
# 0    WI            Expedition Strategies
# 1    WI            Quinnipiac University
# 2    WI                           YouGov
# 3    WI  Marquette University Law School
# 4    WI                          Optimus
#
#                                              sponsor start.date end.date  \
# 0                       Progressive Policy Institute     2/6/20  2/18/20
# 1                                                NaN    2/12/20  2/18/20
# 2  University of Wisconsin‚ÄìMadison | Wiscon...    2/11/20  2/20/20
# 3                                                NaN    2/19/20  2/23/20
# 4                                                NaN     3/5/20   3/7/20
#
#   entry.date.time..et.  number.of.observations population             mode  \
# 0          3/7/20 0:26                     500         rv           Online
# 1        2/20/20 12:05                     823         rv       Live Phone
# 2         2/23/20 8:20                     936         rv           Online
# 3        2/27/20 13:47                    1000         rv       Live Phone
# 4          3/9/20 8:49                     502         lv  Live Phone/Text
#
#    biden  trump  biden_margin  other  undecided  \
# 0  42.00  44.00         -2.00    NaN        NaN
# 1  42.00  49.00         -7.00    NaN        NaN
# 2  45.00  43.00          2.00    NaN        NaN
# 3  46.00  46.00          0.00    NaN        NaN
# 4  43.07  44.56         -1.49    NaN        NaN
#
#                                                  url  include note
# 0  https://www.progressivepolicy.org/wp-content/u...     True  NaN
# 1  https://poll.qu.edu/2020-presidential-swing-st...     True  NaN
# 2   https://news.wisc.edu/battleground-state-poll-1/     True  NaN
# 3  https://law.marquette.edu/poll/wp-content/uplo...     True  NaN
# 4  https://firehousestrategies.com/analysis/march...     True  NaN

# %%
poll.drop(['state', 'pollster', 'sponsor', 'start.date', 'entry.date.time..et.', 'number.of.observations', 'population', 'mode', 'biden', 'trump', 'other', 'undecided', 'url', 'include', 'note'], axis=1, inplace=True)
poll = poll.rename(columns = {'end.date':'ds'})
poll = poll.rename(columns = {'biden_margin':'y'})
poll.head()
# Out:
#         ds     y
# 0  2/18/20 -2.00
# 1  2/18/20 -7.00
# 2  2/20/20  2.00
# 3  2/23/20  0.00
# 4   3/7/20 -1.49

# %%
model = Prophet()
model.fit(poll)
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
poll.tail()
# Out:
#          ds     y
# 39  8/17/20   6.0
# 40  8/19/20  10.0
# 41  8/23/20   5.0
# 42  8/23/20  -1.0
# 43  8/30/20   9.0

# %%
future = model.make_future_dataframe(periods=65)
future.shape
# Out:
# (109, 1)

# %%
future.tail()
# Out:
#             ds
# 104 2020-10-30
# 105 2020-10-31
# 106 2020-11-01
# 107 2020-11-02
# 108 2020-11-03

# %%
poll.shape
# Out:
# (44, 2)

# %%
forecast = model.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#             ds       yhat  yhat_lower  yhat_upper
# 104 2020-10-30  13.964362    9.522246   17.899100
# 105 2020-10-31   8.812088    4.501914   13.086190
# 106 2020-11-01   9.635674    4.985120   13.791416
# 107 2020-11-02  14.045337    9.579715   18.622241
# 108 2020-11-03  12.938541    8.501650   17.170034

# %%
forecast
# Out:
#             ds      trend  yhat_lower  yhat_upper  trend_lower  trend_upper  \
# 0   2020-02-18   0.603523   -2.560454    6.324056     0.603523     0.603523
# 1   2020-02-18   0.603523   -2.634679    5.863999     0.603523     0.603523
# 2   2020-02-20   0.690111   -4.646203    4.113839     0.690111     0.690111
# 3   2020-02-23   0.819993   -5.512151    2.844253     0.819993     0.819993
# 4   2020-03-07   1.382813   -5.759415    2.651256     1.382813     1.382813
# ..         ...        ...         ...         ...          ...          ...
# 104 2020-10-30  11.643449    9.522246   17.899100    11.643449    11.643450
# 105 2020-10-31  11.686743    4.501914   13.086190    11.686743    11.686744
# 106 2020-11-01  11.730037    4.985120   13.791416    11.730037    11.730037
# 107 2020-11-02  11.773331    9.579715   18.622241    11.773330    11.773331
# 108 2020-11-03  11.816625    8.501650   17.170034    11.816624    11.816625
#
#      additive_terms  additive_terms_lower  additive_terms_upper    weekly  \
# 0          1.121916              1.121916              1.121916  1.121916
# 1          1.121916              1.121916              1.121916  1.121916
# 2         -1.037299             -1.037299             -1.037299 -1.037299
# 3         -2.094363             -2.094363             -2.094363 -2.094363
# 4         -2.874656             -2.874656             -2.874656 -2.874656
# ..              ...                   ...                   ...       ...
# 104        2.320913              2.320913              2.320913  2.320913
# 105       -2.874656             -2.874656             -2.874656 -2.874656
# 106       -2.094363             -2.094363             -2.094363 -2.094363
# 107        2.272006              2.272006              2.272006  2.272006
# 108        1.121916              1.121916              1.121916  1.121916
#
#      weekly_lower  weekly_upper  multiplicative_terms  \
# 0        1.121916      1.121916                   0.0
# 1        1.121916      1.121916                   0.0
# 2       -1.037299     -1.037299                   0.0
# 3       -2.094363     -2.094363                   0.0
# 4       -2.874656     -2.874656                   0.0
# ..            ...           ...                   ...
# 104      2.320913      2.320913                   0.0
# 105     -2.874656     -2.874656                   0.0
# 106     -2.094363     -2.094363                   0.0
# 107      2.272006      2.272006                   0.0
# 108      1.121916      1.121916                   0.0
#
#      multiplicative_terms_lower  multiplicative_terms_upper       yhat
# 0                           0.0                         0.0   1.725440
# 1                           0.0                         0.0   1.725440
# 2                           0.0                         0.0  -0.347188
# 3                           0.0                         0.0  -1.274371
# 4                           0.0                         0.0  -1.491843
# ..                          ...                         ...        ...
# 104                         0.0                         0.0  13.964362
# 105                         0.0                         0.0   8.812088
# 106                         0.0                         0.0   9.635674
# 107                         0.0                         0.0  14.045337
# 108                         0.0                         0.0  12.938541
#
# [109 rows x 16 columns]

# %%
fig1 = model.plot(forecast, figsize=(15,8))
plt.title('Biden vs Trump Polling Margin - Michigan', fontsize = 30)
plt.xlabel('Date', fontsize = 16)
plt.ylabel('Biden Margin', fontsize = 16)
plt.grid(b=None)

# %%
fig2 = model.plot_components(forecast)

# %%
fig = model.plot(forecast, figsize=(15, 8))
a = add_changepoints_to_plot(fig.gca(), model, forecast)
plt.title('Biden vs Trump Polling Margin - Wisconsin', fontsize = 30)
plt.xlabel('Date', fontsize = 16)
plt.ylabel('Biden Margin', fontsize = 16)
plt.grid(b=None)

# %% [markdown]
# # Time series forecasting on approval ratings

# %%
approval_ds = pd.read_csv('president_approval_polls - adults 9-10-20 - since 1-2017 - b or better.csv')
approval_ds
# Out:
#       question_id  poll_id  state  politician_id    politician  pollster_id  \
# 0           77265    49253    NaN             11  Donald Trump          169
# 1           77274    49262    NaN             11  Donald Trump          169
# 2           77248    49236    NaN             11  Donald Trump          169
# 3           77599    49426    NaN             11  Donald Trump          744
# 4           77257    49245    NaN             11  Donald Trump          169
# ...           ...      ...    ...            ...           ...          ...
# 3544       128335    68553    NaN             11  Donald Trump          568
# 3545       128295    68529    NaN             11  Donald Trump          568
# 3546       128378    68539    NaN             11  Donald Trump          744
# 3547       128387    68567    NaN             11  Donald Trump          568
# 3548       128350    68557    NaN             11  Donald Trump          568
#
#      pollster sponsor_ids   sponsors display_name  ...  start_date end_date  \
# 0      Gallup         NaN        NaN       Gallup  ...     1/20/17  1/22/17
# 1      Gallup         NaN        NaN       Gallup  ...     1/21/17  1/23/17
# 2      Gallup         NaN        NaN       Gallup  ...     1/22/17  1/24/17
# 3       Ipsos          71    Reuters        Ipsos  ...     1/20/17  1/24/17
# 4      Gallup         NaN        NaN       Gallup  ...     1/23/17  1/25/17
# ...       ...         ...        ...          ...  ...         ...      ...
# 3544   YouGov         352  Economist       YouGov  ...      9/6/20   9/8/20
# 3545   YouGov         NaN        NaN       YouGov  ...      9/5/20   9/8/20
# 3546    Ipsos          71    Reuters        Ipsos  ...      9/3/20   9/8/20
# 3547   YouGov         NaN        NaN       YouGov  ...      9/7/20   9/9/20
# 3548   YouGov         NaN        NaN       YouGov  ...      9/6/20   9/9/20
#
#      sponsor_candidate  tracking    created_at notes  \
# 0                  NaN      True  2/6/17 17:42   NaN
# 1                  NaN      True  2/6/17 17:48   NaN
# 2                  NaN      True  2/6/17 17:40   NaN
# 3                  NaN      True  3/1/17 17:53   NaN
# 4                  NaN      True  2/6/17 17:42   NaN
# ...                ...       ...           ...   ...
# 3544               NaN       NaN  9/9/20 11:18   NaN
# 3545               NaN       NaN  9/8/20 18:16   NaN
# 3546               NaN       NaN  9/9/20 18:01   NaN
# 3547               NaN       NaN  9/9/20 18:58   NaN
# 3548               NaN       NaN  9/9/20 12:29   NaN
#
#                                                     url              source  \
# 0     http://www.gallup.com/poll/201617/gallup-daily...      538 | Huffpost
# 1     http://www.gallup.com/poll/201617/gallup-daily...      538 | Huffpost
# 2     http://www.gallup.com/poll/201617/gallup-daily...      538 | Huffpost
# 3               http://polling.reuters.com/#poll/CP3_2/  Huffpost | Reuters
# 4     http://www.gallup.com/poll/201617/gallup-daily...      538 | Huffpost
# ...                                                 ...                 ...
# 3544  https://docs.cdn.yougov.com/8nwf5tw7g2/econTab...                 538
# 3545  https://docs.cdn.yougov.com/56c1zo4in9/tabs_Tr...                 538
# 3546  https://www.ipsos.com/sites/default/files/ct/n...                 538
# 3547  https://docs.cdn.yougov.com/2hb49ax2ra/tabs_Tr...                 538
# 3548  https://docs.cdn.yougov.com/phral79w4m/tabs_Tr...                 538
#
#        yes    no
# 0     45.0  45.0
# 1     45.0  46.0
# 2     46.0  45.0
# 3     42.1  45.2
# 4     46.0  45.0
# ...    ...   ...
# 3544  42.0  54.0
# 3545  43.0  50.0
# 3546  39.0  56.0
# 3547  40.0  55.0
# 3548  44.0  50.0
#
# [3549 rows x 27 columns]

# %%
# approval_ds.drop(['president','subgroup','modeldate','startdate','pollster','grade','samplesize','population','weight','influence','approve','disapprove',
#                   'adjusted_disapprove','multiversions','tracking','url','poll_id','question_id','createddate','timestamp'], axis=1, inplace=True)
approval_ds = approval_ds.loc[:, ['end_date','yes']]
approval_ds = approval_ds.rename(columns = {'end_date':'ds'})
approval_ds = approval_ds.rename(columns = {'yes':'y'})
approval_ds.head()
# Out:
#         ds     y
# 0  1/22/17  45.0
# 1  1/23/17  45.0
# 2  1/24/17  46.0
# 3  1/24/17  42.1
# 4  1/25/17  46.0

# %%
model = Prophet()
model.fit(approval_ds)
# Out:
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
approval_ds.tail()
# Out:
#           ds     y
# 3544  9/8/20  42.0
# 3545  9/8/20  43.0
# 3546  9/8/20  39.0
# 3547  9/9/20  40.0
# 3548  9/9/20  44.0

# %%
future = model.make_future_dataframe(periods=61)
future.shape
# Out:
# (3610, 1)

# %%
future.tail()
# Out:
#              ds
# 3605 2020-11-05
# 3606 2020-11-06
# 3607 2020-11-07
# 3608 2020-11-08
# 3609 2020-11-09

# %%
forecast = model.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#              ds       yhat  yhat_lower  yhat_upper
# 3605 2020-11-05  41.147647   38.449153   43.673712
# 3606 2020-11-06  41.293246   38.692860   43.802175
# 3607 2020-11-07  41.304531   38.385388   43.939933
# 3608 2020-11-08  41.211641   38.651106   43.792897
# 3609 2020-11-09  41.359034   38.958085   43.818087

# %%
fig1 = model.plot(forecast, figsize=(25, 12))
# plt.title('US President Approval Forecast', fontsize = 30)
plt.xlabel('Date', fontsize = 16)
plt.ylabel('Approval Rate', fontsize = 16)
plt.grid(b=None)

# %%
fig2 = model.plot_components(forecast)

# %%
fig = model.plot(forecast, figsize=(15, 8))
a = add_changepoints_to_plot(fig.gca(), model, forecast)
plt.title('US President Approval Forecast', fontsize = 20)
plt.xlabel('Date', fontsize = 16)
plt.ylabel('Approval Rate', fontsize = 16)
# Out:
# Text(101.75, 0.5, 'Approval Rate')
